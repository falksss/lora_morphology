# %% [markdown]
# # 03 — Full Experiment Grid
#
# **Authors:** Alessandro Aquilini & Joan Lluc Fernández
# **Goal:** Run the complete 3-language × 4-rank training grid and collect results.
#
# ---
# ### Experiment Grid
# | Language | r=4 | r=8 | r=16 | r=32 |
# |----------|-----|-----|------|------|
# | English  |     |     |      |      |
# | Swedish  |     |     |      |      |
# | Spanish  |     |     |      |      |
#
# ### Outline
# 1. Import modules from `src/`
# 2. Define experiment configurations (language × rank)
# 3. Training loop — one run per configuration
# 4. Evaluate surface-form accuracy on test split
# 5. Collect results into a DataFrame
# 6. Plot: LoRA rank vs. accuracy per language
# 7. Secondary analysis: regular vs. irregular verb slices
