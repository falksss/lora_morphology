# %% [markdown]
# # 02 — LoRA Sanity Check
#
# **Author (primary):** Partner B
# **Goal:** Verify that mT5 + PEFT/LoRA loads correctly and that adapter parameters are injected as expected.
#
# ---
# ### Outline
# 1. Load `mT5-small` (or `mT5-base`) via Hugging Face `transformers`
# 2. Wrap with `peft.LoraConfig` for a single rank (e.g. r=8)
# 3. Count trainable vs. frozen parameters
# 4. Run a forward pass on a toy batch — confirm shapes and loss
# 5. Verify Weights & Biases logging initialises cleanly
