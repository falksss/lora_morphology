# %% [markdown]
# # 01 — Data Exploration
#
# **Author (primary):** Partner A
# **Goal:** Inspect UniMorph / SIGMORPHON TSV tables for English, Swedish, and Spanish.
# Verify tokenization behaviour with the mT5 tokenizer.
#
# ---
# ### Outline
# 1. Load raw TSV files from `data/<lang>/`
# 2. Explore paradigm coverage (lemmas, feature tags, surface forms)
# 3. Analyse token length distributions per language
# 4. Check for irregular vs. regular verb splits
# 5. Save cleaned splits to `data/<lang>/train.tsv`, `dev.tsv`, `test.tsv`
